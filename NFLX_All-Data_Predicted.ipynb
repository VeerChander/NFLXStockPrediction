# %% [markdown]
# In this notebook we will be building and training LSTM to predict IBM stock. We will use PyTorch.

# %% [markdown]
# ## 1. Libraries and settings

# %%
import numpy as np
import random
import pandas as pd 
from pylab import mpl, plt
plt.style.use('seaborn')
mpl.rcParams['font.family'] = 'serif'
# %matplotlib inline

# from pandas import datetime
import math, time
import itertools
import datetime
from operator import itemgetter
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from math import sqrt
import torch
import torch.nn as nn
from torch.autograd import Variable
# Out:
# /var/folders/q5/28w4wpqn1jl35m2zwwmqqxq40000gn/T/ipykernel_39577/3861184371.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# ## 2. Load data

# %%
df_nflx = pd.read_csv('NFLXALLDATAwSentiment.csv')
df_nflx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1258 non-null   object
#  1   Open       1258 non-null   float64
#  2   High       1258 non-null   float64
#  3   Low        1258 non-null   float64
#  4   Close      1258 non-null   float64
#  5   Adj Close  1258 non-null   float64
#  6   Volume     1258 non-null   int64
#  7   Sentiment  1258 non-null   int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 78.8+ KB

# %%
df_nflx.drop('Date', inplace=True, axis=1)
df_nflx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1258 non-null   float64
#  1   High       1258 non-null   float64
#  2   Low        1258 non-null   float64
#  3   Close      1258 non-null   float64
#  4   Adj Close  1258 non-null   float64
#  5   Volume     1258 non-null   int64
#  6   Sentiment  1258 non-null   int64
# dtypes: float64(5), int64(2)
# memory usage: 68.9 KB

# %%
scaler = MinMaxScaler(feature_range=(0, 1))

df_nflxSentiment=df_nflx[['Sentiment']]
df_nflxVolume=df_nflx[['Volume']]
df_nflxOpen=df_nflx[['Open']]
df_nflxHigh=df_nflx[['High']]
df_nflxLow=df_nflx[['Low']]
df_nflxAdj_Close=df_nflx[['Adj Close']]

df_nflxSentiment['Sentiment'] = scaler.fit_transform(df_nflxSentiment['Sentiment'].values.reshape(-1,1))
df_nflxVolume['Volume'] = scaler.fit_transform(df_nflxVolume['Volume'].values.reshape(-1,1))
df_nflxOpen['Open'] = scaler.fit_transform(df_nflxOpen['Open'].values.reshape(-1,1))
df_nflxHigh['High'] = scaler.fit_transform(df_nflxHigh['High'].values.reshape(-1,1))
df_nflxLow['Low'] = scaler.fit_transform(df_nflxLow['Low'].values.reshape(-1,1))
df_nflxAdj_Close['Adj Close'] = scaler.fit_transform(df_nflxAdj_Close['Adj Close'].values.reshape(-1,1))
# Out:
# /var/folders/q5/28w4wpqn1jl35m2zwwmqqxq40000gn/T/ipykernel_39577/4138354408.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nflxSentiment['Sentiment'] = scaler.fit_transform(df_nflxSentiment['Sentiment'].values.reshape(-1,1))
# /var/folders/q5/28w4wpqn1jl35m2zwwmqqxq40000gn/T/ipykernel_39577/4138354408.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nflxVolume['Volume'] = scaler.fit_transform(df_nflxVolume['Volume'].values.reshape(-1,1))
# ...

# %%
df_nflx=df_nflx.fillna(method='ffill')

# this the og scaler --> scaler = MinMaxScaler(feature_range=(-1, 1))

#new scaler
scaler = MinMaxScaler(feature_range=(0, 1))

df_nflx['Close'] = scaler.fit_transform(df_nflx['Close'].values.reshape(-1,1))
df_nflx['Sentiment'] = scaler.fit_transform(df_nflx['Sentiment'].values.reshape(-1,1))
df_nflx['Volume'] = scaler.fit_transform(df_nflx['Volume'].values.reshape(-1,1))
df_nflx['Open'] = scaler.fit_transform(df_nflx['Open'].values.reshape(-1,1))
df_nflx['High'] = scaler.fit_transform(df_nflx['High'].values.reshape(-1,1))
df_nflx['Low'] = scaler.fit_transform(df_nflx['Low'].values.reshape(-1,1))
df_nflx['Adj Close'] = scaler.fit_transform(df_nflx['Adj Close'].values.reshape(-1,1))


# 1 is positive, 0 is nuetral -1 negative

# %%
# function to create train, test data given stock data and sequence length
def load_data(stock, look_back):
    data_raw = stock.values # convert to numpy array
    data = []
    
    # create all possible sequences of length look_back
    for index in range(len(data_raw) - look_back): 
        data.append(data_raw[index: index + look_back])
    
    data = np.array(data);
    test_set_size = int(np.round(0.2*data.shape[0]));
    train_set_size = data.shape[0] - (test_set_size);
    
    x_train = data[:train_set_size,:-1,:]
    y_train = data[:train_set_size,-1,:]
    
    x_test = data[train_set_size:,:-1]
    y_test = data[train_set_size:,-1,:]
    
    return [x_train, y_train, x_test, y_test, test_set_size, train_set_size]

look_back = 60 # choose sequence length
x_train, y_train, x_test, y_test, test_size, train_size = load_data(df_nflx, look_back)
print('x_train.shape = ',x_train.shape ,x_train.ndim)
print('y_train.shape = ',y_train.shape)
print('x_test.shape = ',x_test.shape)
print('y_test.shape = ',y_test.shape)
# Out:
# x_train.shape =  (958, 59, 7) 3
# y_train.shape =  (958, 7)
# x_test.shape =  (240, 59, 7)
# y_test.shape =  (240, 7)

# %%
# make training and test sets in torch
x_train = torch.from_numpy(x_train).type(torch.Tensor)
x_test = torch.from_numpy(x_test).type(torch.Tensor)
y_train = torch.from_numpy(y_train).type(torch.Tensor)
y_test = torch.from_numpy(y_test).type(torch.Tensor)

# %% [markdown]
# ## 3. Build the structure of model

# %%
# Build model
#####################
input_dim = 7
hidden_dim = 32
num_layers = 2 
output_dim = 1


# Here we define our model as a class
class LSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super(LSTM, self).__init__()
        # Hidden dimensions
        self.hidden_dim = hidden_dim

        # Number of hidden layers
        self.num_layers = num_layers

        # batch_first=True causes input/output tensors to be of shape
        # (batch_dim, seq_dim, feature_dim)
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)

        # Readout layer
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        # Initialize hidden state with zeros
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).requires_grad_()

        # Initialize cell state
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).requires_grad_()

        # We need to detach as we are doing truncated backpropagation through time (BPTT)
        # If we don't, we'll backprop all the way to the start even after going through another batch
        out, (hn, cn) = self.lstm(x, (h0.detach(), c0.detach()))

        # Index hidden state of last time step
        # out.size() --> 100, 32, 100
        # out[:, -1, :] --> 100, 100 --> just want last time step hidden states! 
        out = self.fc(out[:, -1, :]) 
        # out.size() --> 100, 10
        return out
    
model = LSTM(input_dim=input_dim, hidden_dim=hidden_dim, output_dim=output_dim, num_layers=num_layers)
loss_fn = torch.nn.MSELoss()
optimiser = torch.optim.Adam(model.parameters(), lr=0.01)
print(model)
print(len(list(model.parameters())))
for i in range(len(list(model.parameters()))):
    print(list(model.parameters())[i].size())
# Out:
# LSTM(
#   (lstm): LSTM(7, 32, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=32, out_features=1, bias=True)
# )
# 10
# torch.Size([128, 7])
# torch.Size([128, 32])
# torch.Size([128])
# torch.Size([128])
# torch.Size([128, 32])
# torch.Size([128, 32])
# torch.Size([128])
# torch.Size([128])
# torch.Size([1, 32])
# torch.Size([1])

# %%
# Train model
#####################
num_epochs = 100
hist = np.zeros(num_epochs)

# Number of steps to unroll
seq_dim =look_back-1  

for t in range(num_epochs):
    # Initialise hidden state
    # Don't do this if you want your LSTM to be stateful
    #model.hidden = model.init_hidden()
    
    # Forward pass
    y_train_pred = model(x_train)
    loss = loss_fn(y_train_pred, y_train)
    if t % 10 == 0 and t !=0:
        print("Epoch ", t, "MSE: ", loss.item())
    hist[t] = loss.item()

    # Zero out gradient, else they will accumulate between epochs
    optimiser.zero_grad()

    # Backward pass
    loss.backward()

    # Update parameters
    optimiser.step()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/loss.py:536: UserWarning: Using a target size (torch.Size([958, 7])) that is different to the input size (torch.Size([958, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch  10 MSE:  0.06051911041140556
# Epoch  20 MSE:  0.05722561106085777
# Epoch  30 MSE:  0.05437757447361946
# Epoch  40 MSE:  0.05326129123568535
# Epoch  50 MSE:  0.05265286564826965
# Epoch  60 MSE:  0.052533503621816635
# Epoch  70 MSE:  0.052446186542510986
# Epoch  80 MSE:  0.052414555102586746
# Epoch  90 MSE:  0.05238143727183342

# %%
plt.plot(hist, label="Training loss")
plt.legend()
plt.show()

# %%
results = np.array([])
target_shape = (1, seq_dim, 7)
count = train_size + seq_dim



reshaped_tensor = x_test[0].view(target_shape)
for i in range(test_size):
    with torch.no_grad():
        y_test_pred = model(reshaped_tensor)
    

    temp_valSentiment = df_nflxSentiment.iloc[count][0]
    temp_valVolume = df_nflxVolume.iloc[count][0]
    temp_valOpen = df_nflxOpen.iloc[count][0]
    temp_valHigh = df_nflxHigh.iloc[count][0]
    temp_valLow = df_nflxLow.iloc[count][0]
    temp_valAdj_Close = df_nflxAdj_Close.iloc[count][0]


    new_tensor = torch.tensor([[temp_valSentiment,temp_valVolume,temp_valOpen,temp_valHigh,temp_valLow,temp_valAdj_Close]])
    
    count = count + 1
    
    #Preparing info to be added
    smaller_tensor = torch.cat((y_test_pred, new_tensor), dim=1)
    smaller_tensor = smaller_tensor.unsqueeze(0)
    smaller_tensor = torch.tensor(smaller_tensor.tolist())
    
    
    
    #Info is added
    reshaped_tensor = torch.cat((reshaped_tensor, smaller_tensor), dim=1)
    
    #Slicing the first index 
    reshaped_tensor = reshaped_tensor[:, 1:]

    # the results from predicted info
    y_test_pred = y_test_pred.detach().numpy()
    results = np.append(results, y_test_pred)

# %%
# make predictions
# y_test_pred = model(x_test)

# invert predictions
y_train_pred = scaler.inverse_transform(y_train_pred.detach().numpy())
y_train = scaler.inverse_transform(y_train.detach().numpy())
results = scaler.inverse_transform(results.reshape(-1,1))
y_test = scaler.inverse_transform(y_test.detach().numpy())

# calculate root mean squared error
# trainScore = math.sqrt(mean_squared_error(y_train[:,0], y_train_pred[:,0]))
# print('Train Score: %.2f RMSE' % (trainScore))
# testScore = math.sqrt(mean_squared_error(y_test[:,0], y_test_pred[:,0]))
# print('Test Score: %.2f RMSE' % (testScore))
# trainScore2 = mean_squared_error(y_train[:,0], y_train_pred[:,0])
# print('Train Score: %.2f RMSE' % (trainScore2))

# %%
trial = pd.DataFrame(results)
trial.plot()
# Out:
# <Axes: >

# %%
# Visualising the results
figure, axes = plt.subplots(figsize=(15, 6))
y_test = y_test[:, 0].reshape(test_size, 1)

#12/8/2022 to 11/26/2023

axes.plot(df_nflx[len(df_nflx)-len(y_test):].index, y_test, color = 'red', label = 'Real NFLX Stock Price')
axes.plot(df_nflx[len(df_nflx)-len(y_test):].index, results, color = 'blue', label = 'Predicted NFL Stock Price')


plt.title('NFLX Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('NFLX Stock Price')
plt.legend()
plt.show()
